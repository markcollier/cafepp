# %% [markdown]
# # checking cafe raw model files for CF conformance
#
# cd /OSM/CBR/OA_DCFP/work/col414/CAFEPP
#
# scp mac599@raijin.nci.org.au:/short/v14/pas548/cm-runs/CAFE-88-T4/20100101/atmos_daily_2010_01_01.nc tmp/.
# scp mac599@raijin.nci.org.au:/short/v14/pas548/cm-runs/CAFE-88-T4/20100101/ocean_daily_2010_01_01.nc tmp/.
# scp mac599@raijin.nci.org.au:/short/v14/pas548/cm-runs/CAFE-88-T4/20100101/ocean_bgc_daily_2010_01_01.nc tmp/.
# scp mac599@raijin.nci.org.au:/short/v14/pas548/cm-runs/CAFE-88-T4/20100101/ice_daily_2010_01_01.nc tmp/.
# scp mac599@raijin.nci.org.au:/short/v14/pas548/cm-runs/CAFE-88-T4/20100101/land_daily_2010_01_01.nc tmp/.
# scp mac599@raijin.nci.org.au:/short/v14/pas548/cm-runs/CAFE-88-T4/20100101/ocean_bgc_daily_extra_2010_01_01.nc tmp/.
# scp mac599@raijin.nci.org.au:/short/v14/pas548/cm-runs/CAFE-88-T4/20100101/ocean_daily_extra_2010_01_01.nc tmp/.
# scp mac599@raijin.nci.org.au:/short/v14/pas548/cm-runs/CAFE-88-T4/20100101/ocean_force_2010_01_01.nc tmp/.
# scp mac599@raijin.nci.org.au:/short/v14/pas548/cm-runs/CAFE-88-T4/20100101/ocean_scalar_2010_01_01.nc tmp/.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
#scp mac599@raijin.nci.org.au:/short/v14/pas548/cm-runs/CAFE-88-T4/20100101/atmos_daily_2010_01_01.nc .

# %%
import sys
import shlex
from subprocess import Popen, PIPE
import inspect
import shutil

__file__='jupyter_notebook' #this can be deleted when written to a python script and loaded as module.

def get_exitcode_stdout_stderr(cmd):
    """
    Execute the external command and get its exitcode, stdout and stderr.
    """
    args = shlex.split(cmd)
 
    proc = Popen(args, stdout=PIPE, stderr=PIPE)
    out, err = proc.communicate()
    exitcode = proc.returncode
    #
    return exitcode, out, err

CRED = '\033[91m'
CEND = '\033[0m'

# %%
idir='/OSM/CBR/OA_DCFP/work/col414/CAFEPP/tmp'

tdir='/OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary'

ifil=['atmos_daily_2010_01_01.nc',
'ocean_daily_2010_01_01.nc',
'ocean_bgc_daily_2010_01_01.nc',
'ice_daily_2010_01_01.nc',
'land_daily_2010_01_01.nc',
'ocean_bgc_daily_extra_2010_01_01.nc',
'ocean_daily_extra_2010_01_01.nc',
'ocean_force_2010_01_01.nc',
'ocean_scalar_2010_01_01.nc']

ifils=[]
for f in ifil:
  ifils.append(idir+'/'+f)
  
print(ifils)

#raise SystemExit('Forced exit file:'+__file__+' line number: '+str(inspect.stack()[0][2]))

# command='cfchecks ' + ifils[0]

# status, out, err = get_exitcode_stdout_stderr(command)

#shutil.copyfile(idir+'/'+ifil[1],tdir+'/'+ifil[1])

command='cfchecks ' + tdir+'/'+ifil[1]

status, out, err = get_exitcode_stdout_stderr(command)

#print('status, out, err=',status, out, err)
#print('out=',out)

print(out.replace('\\n', '\n'))

print('END')
# Out:
# ['/OSM/CBR/OA_DCFP/work/col414/CAFEPP/tmp/atmos_daily_2010_01_01.nc', '/OSM/CBR/OA_DCFP/work/col414/CAFEPP/tmp/ocean_daily_2010_01_01.nc', '/OSM/CBR/OA_DCFP/work/col414/CAFEPP/tmp/ocean_bgc_daily_2010_01_01.nc', '/OSM/CBR/OA_DCFP/work/col414/CAFEPP/tmp/ice_daily_2010_01_01.nc', '/OSM/CBR/OA_DCFP/work/col414/CAFEPP/tmp/land_daily_2010_01_01.nc', '/OSM/CBR/OA_DCFP/work/col414/CAFEPP/tmp/ocean_bgc_daily_extra_2010_01_01.nc', '/OSM/CBR/OA_DCFP/work/col414/CAFEPP/tmp/ocean_daily_extra_2010_01_01.nc', '/OSM/CBR/OA_DCFP/work/col414/CAFEPP/tmp/ocean_force_2010_01_01.nc', '/OSM/CBR/OA_DCFP/work/col414/CAFEPP/tmp/ocean_scalar_2010_01_01.nc']
# CHECKING NetCDF FILE: /OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary/ocean_daily_2010_01_01.nc
# ...
# Using CF Checker Version 3.0.5
# Checking against CF Version CF-1.6
# Using Standard Name Table Version 60 (2018-10-16T11:02:46Z)
# Using Area Type Table Version 9 (04 July 2018)
#
#
# ------------------
# Checking variable: xt_ocean
# ------------------
#
# ...

# %% [markdown]
# atmos_daily_2010_01_01.nc
# ncatted -a cell_methods,t_ref_min,o,c,"time: minimum" /OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary/atmos_daily_2010_01_01.nc
# ncatted -a cell_methods,t_ref_max,o,c,"time: maximum" /OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary/atmos_daily_2010_01_01.nc
# ncatted -a units,time_bounds,o,c,"days since 1970-01-01 00:00:00" /OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary/atmos_daily_2010_01_01.nc
# ncatted -a missing_value,time_bounds,d,, /OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary/atmos_daily_2010_01_01.nc
# ncatted -a _FillValue,time_bounds,d,, /OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary/atmos_daily_2010_01_01.nc
#
# ocean_daily_2010_01_01.nc
# ncatted -a units,temp,o,c,"degree_Celsius" /OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary/ocean_daily_2010_01_01.nc
# ncatted -a units,sst,o,c,"degree_Celsius" /OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary/ocean_daily_2010_01_01.nc
# ncatted -a coordinates,eta_t,d,, /OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary/ocean_daily_2010_01_01.nc
# ncatted -a coordinates,salt,d,, /OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary/ocean_daily_2010_01_01.nc
# ncatted -a coordinates,temp,d,, /OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary/ocean_daily_2010_01_01.nc
# ncatted -a coordinates,u,d,, /OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary/ocean_daily_2010_01_01.nc
# ncatted -a coordinates,v,d,, /OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary/ocean_daily_2010_01_01.nc
# ncatted -a coordinates,wt,d,, /OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary/ocean_daily_2010_01_01.nc
# ncatted -a coordinates,sst,d,, /OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary/ocean_daily_2010_01_01.nc
# ncatted -a coordinates,mld,d,, /OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary/ocean_daily_2010_01_01.nc
# ncatted -a units,time_bounds,o,c,"days since 1970-01-01 00:00:00" /OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary/ocean_daily_2010_01_01.nc
# ncatted -a missing_value,time_bounds,d,, /OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary/ocean_daily_2010_01_01.nc
# ncatted -a _FillValue,time_bounds,d,, /OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary/ocean_daily_2010_01_01.nc
# ncatted -a Conventions,global,o,c,"CF-1.6" /OSM/CBR/OA_DCFP/work/col414/CAFEPP/temporary/ocean_daily_2010_01_01.nc

# %% [markdown]
# BEGIN
#
# ocean_scalar_2010_01_01.nc
#
# time_bounds:units = "days" ;
# to:
# time_bounds:units = "days since 1970-01-01 00:00:00" ; #or whatever is in time:units
#
# add global attribute:
# Conventions = "CF-1.6"
#
# ocean_force_2010_01_01.nc
#
# remove from all variables:
# coordinates = "geolon_t geolat_t" ;
#
# time_bounds:units = "days" ;
# to:
# time_bounds:units = "days since 1970-01-01 00:00:00" ; #or whatever is in time:units
#
# add global attribute:
# Conventions = "CF-1.6"
#
# ocean_daily_extra_2010_01_01.nc
#
# remove from all variables:
# coordinates = "geolon_t geolat_t" ;
#
# time_bounds:units = "days" ;
# to:
# time_bounds:units = "days since 1970-01-01 00:00:00" ; #or whatever is in time:units
#
# add global attribute:
# Conventions = "CF-1.6"
#
# ocean_bgc_daily_extra_2010_01_01.nc
#
# remove from all variables:
# coordinates = "geolon_t geolat_t" ;
#
# time_bounds:units = "days" ;
# to:
# time_bounds:units = "days since 1970-01-01 00:00:00" ; #or whatever is in time:units
#
# add global attribute:
# Conventions = "CF-1.6"
#
# land_daily_2010_01_01.nc
#
# time_bounds:units = "days" ;
# to:
# time_bounds:units = "days since 1970-01-01 00:00:00" ; #or whatever is in time:units
#
# add global attribute:
# Conventions = "CF-1.6"
#
#
# ice_daily_2010_01_01.nc
#
# time_bounds:units = "days" ;
# to:
# time_bounds:units = "days since 1970-01-01 00:00:00" ; #or whatever is in time:units
#
# add global attribute:
# Conventions = "CF-1.6"
#
# ocean_bgc_daily_2010_01_01.nc
#
# Changes as for ocean_daily_2010_01_01.nc
#
# plus:
#
# pco2 & co2 need to have units specified.
#
# ocean_daily_2010_01_01.nc
#
# remove from all variables:
# coordinates = "geolon_t geolat_t" ;
#
# add global attribute:
# Conventions = "CF-1.6"
#
# variable temp & sst should strictly have units of K in which case data would need to be converted. It uses standard_name and compares to values in http://cfconventions.org/Data/cf-standard-names/current/build/cf-standard-name-table.html
#
# atmos_daily_2010_01_01.nc
#
# change:
#
# t_ref_min:cell_methods = "time: min" ;
# to:
# t_ref_min:cell_methods = "time: minimum" ;
#
# t_ref_max:cell_methods = "time: max" ;
# to:
# t_ref_max:cell_methods = "time: maximum" ;
#
# time_bounds:units = "days" ;
# to:
# time_bounds:units = "days since 1970-01-01 00:00:00" ; #or whatever is in time:units
#
# add global attribute:
# Conventions = "CF-1.6"
#
# END
