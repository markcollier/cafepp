# %% [markdown]
# # Examine QBO features in key runs:

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
print('BEGIN')

import socket
import re
import os
import sys
import inspect
import pickle
import glob
#import sort

import socket
import re
import os
import sys

print('sys.version=',sys.version)

hostname=socket.gethostname()

print('hostname=',hostname)

if(re.match('raijin',hostname)):
  print('this is rajin')
  rundir='/short/v14/mac599/cafepp/rundir'
  topdir=''
elif(re.match('oa-3.-cdc',hostname)):
  print('this is vm32')
  rundir='/OSM/CBR/OA_DCFP/work/col414/cafepp'
  topdir='/OSM/CBR/OA_DCFP/data/CAFEPP/CMIP6'
  topdir='/OSM/CBR/OA_DCFP/work/col414/CAFEPP/CMIP6'
  topdir_vm='/OSM/CBR/OA_DCFP/data/CAFEPP'
  topdir_vm='/OSM/CBR/OA_DCFP/work/col414/CAFEPP'
  
os.chdir(rundir)

os.chdir('/OSM/CBR/OA_DCFP/work/col414/cafepp')

print('Current Working Directory=',os.getcwd())

__file__='jupyter_notebook' #this can be deleted when written to a python script and loaded as module.

import cartopy.crs as ccrs
from cartopy.util import add_cyclic_point
import numpy as np
import numpy.ma as ma
from matplotlib.mlab import griddata

from decadal_diag import \
  fractional_year_from_num2date, \
  generate_daily_month_indices, \
  shade_2d_latlon, \
  get_timestamp_number, \
  shade_2d_curvilinear, \
  shade_2d_simple, \
  nino_indices, \
  plot_xy, \
  fractional_year_from_num2date

from n_data_funcs import n_data_funcs
  
cafe_experiment_titles = {1:'v0_forecast', 4:'v1_forecast', 3:'v2_forecast', 9:'v1', \
  5:'v2', 6:'v3', 7:'aug17p', 2:'v1_assim', 10:'etkf', 11:'nov17n', 12:'jul18b', 13:'v0'}

fluxes_colors={'hfls':'red', 'hfss':'blue', 'rlds':'green', 'rlus':'orange', \
               'rlut':'pink', 'rsdt':'brown', 'rsus':'cyan', 'rsds':'purple', 'rsut':'grey', \
              'net down toa':'tan', 'net down surf':'yellow'}

# %matplotlib inline

CRED = '\033[91m'
CEND = '\033[0m'

#print(cafe_experiment_titles[1])

print('END')
# Out:
# BEGIN
# sys.version= 3.6.6 |Anaconda, Inc.| (default, Jun 28 2018, 17:14:51)
# [GCC 7.2.0]
# hostname= oa-35-cdc
# this is vm32
# Current Working Directory= /OSM/CBR/OA_DCFP/work/col414/cafepp
# END

# %%
print('BEGIN')

SWITCH_OFF=True #temporary for easy skipping of this section.
SWITCH_OFF=False

if(not SWITCH_OFF):
  
#===============================================================================

  product='ncepr2'
  ivar_str_ncepr2='uwnd';ifil_prefix_ncepr2='uwnd';offset_ncepr2=0.0;scale_ncepr2=1.0;long_name_ncepr2='Zonal Winds';short_name_ncepr2='uwnd';units_ncepr2='ms-1'
  ncepr2_calendar='proleptic_gregorian'
  idir=topdir_vm+'/short/v14/mac599/ncep2/monthly_averages'
  ncepr2_monthly_files=[[idir+'/'+ifil_prefix_ncepr2+'.mon.mean.nc']]

  print('ncepr2_monthly_files=',ncepr2_monthly_files)
  
  #raise SystemExit('STOP!:'+__file__+' line number: '+str(inspect.stack()[0][2]))
  
#===============================================================================

  model='CAFE'
  grid_label='gn'
    
  ivar_str_cafe='ua';offset=0.0;scale=1.0;long_name='Zonal Winds';short_name='ua';units='ms-1';table='Amon'

  ensemble=1
  pval=13

  cafe_monthly_files_aug18b=[]
  idir=topdir+'/'+'CMIP6/CMIP/CSIRO/CAFE-1-0/historical/r'+str(ensemble)+'i1p'+str(pval)+'f1/'+table+ \
    '/'+ivar_str_cafe+'/'+grid_label+'/v20171025'
  monthly_ifils_aug18b=[ivar_str_cafe+'_'+table+'_historical_CAFE-1-0_r'+str(ensemble)+'i1p'+str(pval)+'f1_'+ \
    grid_label+'_198001-200912.nc']
  for file in monthly_ifils_aug18b:
    if(not os.path.exists(idir+'/'+file)):
      raise SystemExit(idir+'/'+file+' doesnt exist:'+__file__+' line number: '+str(inspect.stack()[0][2]))
    else:
      cafe_monthly_files_aug18b.append(idir+'/'+file)
  cafe_monthly_files_aug18b=[cafe_monthly_files_aug18b]

  print('cafe_monthly_files_aug18b=',cafe_monthly_files_aug18b)

  #raise SystemExit('STOP!:'+__file__+' line number: '+str(inspect.stack()[0][2]))
  
#===============================================================================

  ensemble=1
  pval=14
  
  ivar_str_cafe='ua';offset=0.0;scale=1.0;long_name='Zonal Winds';short_name='ua';units='ms-1';table='Amon'

  cafe_monthly_files_sep18a=[]
  idir=topdir+'/'+'CMIP6/CMIP/CSIRO/CAFE-1-0/historical/r'+str(ensemble)+'i1p'+str(pval)+'f1/'+table+ \
    '/'+ivar_str_cafe+'/'+grid_label+'/v20171025'
  monthly_ifils_sep18a=[ivar_str_cafe+'_'+table+'_historical_CAFE-1-0_r'+str(ensemble)+'i1p'+str(pval)+'f1_'+ \
    grid_label+'_198001-200912.nc']
  for file in monthly_ifils_sep18a:
    if(not os.path.exists(idir+'/'+file)):
      raise SystemExit(idir+'/'+file+' doesnt exist:'+__file__+' line number: '+str(inspect.stack()[0][2]))
    else:
      cafe_monthly_files_sep18a.append(idir+'/'+file)
  cafe_monthly_files_sep18a=[cafe_monthly_files_sep18a]

  print('cafe_monthly_files_sep18a=',cafe_monthly_files_sep18a)

  #raise SystemExit('STOP!:'+__file__+' line number: '+str(inspect.stack()[0][2]))
  
#===============================================================================

  AnnOut=False
  #AnnOut=True
  
  ZeroClim=False
  #ZeroClim=True
  
#===============================================================================

  print(CRED+'Processing monthly NCEP...'+CEND) #1948-2018
  
  cbeg=1981
  cend=2000
  abeg=1979
  aend=2017
  
  ncepr2_file_var_from_monthly=n_data_funcs(Diag=False, input_files=ncepr2_monthly_files, input_var_name=ivar_str_ncepr2)

  ncepr2_file_var_from_monthly.calculate_filedatetime_info(Diag=False,calendar=ncepr2_calendar)

  ncepr2_file_var_from_monthly.get_latlon_info(Diag=False)
  
  ncepr2_file_var_from_monthly.get_lev_info(Diag=False, lev='level')

  ncepr2_monthly_quantity_from_monthly=ncepr2_file_var_from_monthly.calculate_quantity('dummy', Diag=True, quantity='latlon_region') 

  ncepr2_quantity_monthlyclimatology_from_monthly, ncepr2_quantity_monthlyanomaly_from_monthly=ncepr2_file_var_from_monthly.monthly_clim_anom( \
    Diag=False, input=ncepr2_monthly_quantity_from_monthly, AnnOut=AnnOut, ZeroClim=ZeroClim, cbeg=cbeg, cend=cend, abeg=abeg, aend=aend)
  
  print('ncepr2_quantity_monthlyanomaly_from_monthly.shape=',ncepr2_quantity_monthlyanomaly_from_monthly.shape)

  #raise SystemExit('STOP!:'+__file__+' line number: '+str(inspect.stack()[0][2]))

#===============================================================================

  cbeg=1981
  cend=2000
  abeg=1980
  aend=2009
  
  print(CRED+'Processing monthly cafe aug18b ...'+CEND)

  cafe_monthly_files_aug18b=n_data_funcs(input_files=cafe_monthly_files_aug18b, input_var_name=ivar_str_cafe)

  cafe_monthly_files_aug18b.calculate_filedatetime_info(calendar='noleap')

  cafe_monthly_files_aug18b.get_latlon_info(Diag=False)

  cafe_monthly_files_aug18b.get_lev_info(Diag=False, lev='plev')

  cafe_quantity_monthly_aug18b=cafe_monthly_files_aug18b.calculate_quantity('dummy', quantity='latlon_region')

  cafe_quantity_monthlyclimatology_from_monthly_aug18b, cafe_quantity_monthlyanomaly_from_monthly_aug18b=cafe_monthly_files_aug18b.monthly_clim_anom( \
    Diag=False, input=cafe_quantity_monthly_aug18b, AnnOut=AnnOut, ZeroClim=ZeroClim, \
    cbeg=cbeg, cend=cend, abeg=abeg, aend=aend)
  
  print('cafe_quantity_monthlyanomaly_from_monthly_aug18b.shape=',cafe_quantity_monthlyanomaly_from_monthly_aug18b.shape)

#   #raise SystemExit('STOP!:'+__file__+' line number: '+str(inspect.stack()[0][2]))

#===============================================================================

  cbeg=1981
  cend=2000
  abeg=1980
  aend=2009
  
  print(CRED+'Processing monthly cafe sep18a ...'+CEND)

  cafe_monthly_files_sep18a=n_data_funcs(input_files=cafe_monthly_files_sep18a, input_var_name=ivar_str_cafe)

  cafe_monthly_files_sep18a.calculate_filedatetime_info(calendar='noleap')

  cafe_monthly_files_sep18a.get_latlon_info(Diag=False)

  cafe_monthly_files_sep18a.get_lev_info(Diag=False, lev='plev')
    
  cafe_quantity_monthly_sep18a=cafe_monthly_files_sep18a.calculate_quantity('dummy', quantity='latlon_region')

  cafe_quantity_monthlyclimatology_from_monthly_sep18a, cafe_quantity_monthlyanomaly_from_monthly_sep18a=cafe_monthly_files_sep18a.monthly_clim_anom( \
    Diag=False, input=cafe_quantity_monthly_sep18a, AnnOut=AnnOut, ZeroClim=ZeroClim, \
    cbeg=cbeg, cend=cend, abeg=abeg, aend=aend)
  
  print('cafe_quantity_monthlyanomaly_from_monthly_sep18a.shape=',cafe_quantity_monthlyanomaly_from_monthly_sep18a.shape)

  #raise SystemExit('STOP!:'+__file__+' line number: '+str(inspect.stack()[0][2]))

print('END')
# Out:
# BEGIN
# ncepr2_monthly_files= [['/OSM/CBR/OA_DCFP/work/col414/CAFEPP/short/v14/mac599/ncep2/monthly_averages/uwnd.mon.mean.nc']]
# cafe_monthly_files_aug18b= [['/OSM/CBR/OA_DCFP/work/col414/CAFEPP/CMIP6/CMIP6/CMIP/CSIRO/CAFE-1-0/historical/r1i1p13f1/Amon/ua/gn/v20171025/ua_Amon_historical_CAFE-1-0_r1i1p13f1_gn_198001-200912.nc']]
# cafe_monthly_files_sep18a= [['/OSM/CBR/OA_DCFP/work/col414/CAFEPP/CMIP6/CMIP6/CMIP/CSIRO/CAFE-1-0/historical/r1i1p14f1/Amon/ua/gn/v20171025/ua_Amon_historical_CAFE-1-0_r1i1p14f1_gn_198001-200912.nc']]
# Processing monthly NCEP...
# n_data_funcs.init: no ensembles in this example.
# calculate_filedatetime_info: case 1: no ensembles, one input file.
# calculate_quantity: Turning on diagnostics.
# calculate_quantity: Diag= True
# calculate_quantity: key,value= quantity latlon_region
# calculate_quantity: calculating a quantity...
# calculate_quantity: value_split= ['latlon_region']
# calculate_quantity: latlon_region chosen.
# ...

# %%
print(ncepr2_file_var_from_monthly.lat)

print(ncepr2_file_var_from_monthly.lat[34:38+1])

print(cafe_monthly_files_aug18b.lat[42:47+1])

# %%
print('BEGIN')

xysize=(18,4)

shade_2d_simple(np.transpose(np.average(np.average(ncepr2_quantity_monthlyanomaly_from_monthly[:,:,34:38+1,:],axis=3),axis=2)), \
  title='ncep2', units='m/s', \
  reverse_yaxis=True, yscale='log', \
  xyvals=(ncepr2_file_var_from_monthly.year_fraction_anomaly, ncepr2_file_var_from_monthly.lev), \
  xysize=xysize, xlab='Time (Year)', ylab='Pressure (hPa)', ytik=[10,100,500,1000], grid=True, clevs=None, n_contour=[0])

shade_2d_simple(np.transpose(np.average(np.average(cafe_quantity_monthlyanomaly_from_monthly_aug18b[:,:,42:47+1,:],axis=3),axis=2)), \
  title='cafe aug18b', units='m/s', \
  reverse_yaxis=True, yscale='log', \
  xyvals=(cafe_monthly_files_aug18b.year_fraction_anomaly, cafe_monthly_files_aug18b.lev/100.), \
  xysize=xysize, xlab='Time (Year)', ylab='Pressure (hPa)', ytik=[10,100,500,1000], grid=True, clevs=None, n_contour=[0])

shade_2d_simple(np.transpose(np.average(np.average(cafe_quantity_monthlyanomaly_from_monthly_sep18a[:,:,42:47+1,:],axis=3),axis=2)), \
  title='cafe sep18a', units='m/s', \
  reverse_yaxis=True, yscale='log', \
  xyvals=(cafe_monthly_files_sep18a.year_fraction_anomaly, cafe_monthly_files_sep18a.lev/100.), \
  xysize=xysize, xlab='Time (Year)', ylab='Pressure (hPa)', ytik=[10,100,500,1000], grid=True, clevs=None, n_contour=[0])

raise SystemExit('STOP!:'+__file__+' line number: '+str(inspect.stack()[0][2]))

xysize=(6,4)

shade_2d_simple(np.average(np.average(ncepr2_quantity_monthlyclimatology_from_monthly,axis=0),axis=2), \
  title='ncep2', units='m/s', \
  reverse_yaxis=True, yscale='log', \
  xyvals=(ncepr2_file_var_from_monthly.lat, ncepr2_file_var_from_monthly.lev), \
  xysize=xysize, xlab='Latitude', ylab='Pressure (hPa)', ytik=[10,100,500,1000], grid=True, clevs=None, n_contour=[0])

shade_2d_simple(np.average(np.average(cafe_quantity_monthlyclimatology_from_monthly_aug18b,axis=0),axis=2), \
  title='cafe aug18b', units='m/s', \
  reverse_yaxis=True, yscale='log', \
  xyvals=(cafe_monthly_files_aug18b.lat, cafe_monthly_files_aug18b.lev/100.), \
  xysize=xysize, xlab='Latitude', ylab='Pressure (hPa)', ytik=[10,100,500,1000], grid=True, clevs=None, n_contour=[0])

shade_2d_simple(np.average(np.average(cafe_quantity_monthlyclimatology_from_monthly_sep18a,axis=0),axis=2), \
  title='cafe sep18a', units='m/s', \
  reverse_yaxis=True, yscale='log', \
  xyvals=(cafe_monthly_files_sep18a.lat, cafe_monthly_files_sep18a.lev/100.), \
  xysize=xysize, xlab='Latitude', ylab='Pressure (hPa)', ytik=[10,100,500,1000], grid=True, clevs=None, n_contour=[0])

print('END')
# Out:
# BEGIN
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: STOP!:jupyter_notebook line number: 11
# /OSM/CBR/OA_DCFP/apps/col414/anaconda3/envs/cafepp_36_new/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2971: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
print('BEGIN')

plevs_raw_jra55=[1,10,100,1000,125,150,175,2,20,200,225,250,3,30,300,350,400,450,5,50,500,550,600,650,7,70,750,775,800,825,850,875,900,925,950,975]

plevs_jra55=sorted(plevs_raw_jra55)

#plevs_jra55=[100, 300, 500, 700, 900,1000] #dummy values for testing/speed.
#plevs_jra55=[100, 300] #dummy values for testing/speed.
#plevs_jra55=[1, 2, 3, 5, 7, 10, 20, 30, 50, 70, 100] #dummy values for testing/speed.

print(plevs_jra55)

#raise SystemExit('STOP!:'+__file__+' line number: '+str(inspect.stack()[0][2]))

AnnOut=False
#AnnOut=True

ZeroClim=False
#ZeroClim=True

for plev_cnt,plev in enumerate(plevs_jra55):
  print('plev_cnt,plev=',plev_cnt,plev)
  
  idir_jra55='/OSM/CBR/OA_DCFP/data/observations/JRA55/isobaric/033_ugrd/cat'
  ifil_jra55='jra.55.ugrd.'+str(plevs_jra55[plev_cnt])+'.1958010100_2016123118.nc'

  print('Input file=',idir_jra55+'/'+ifil_jra55)

  cbeg_jra55=1981
  cend_jra55=2000
  abeg_jra55=1958
  aend_jra55=2016

  grid_label='jra55'

  jra55_daily=n_data_funcs(Diag=False, input_files=[[idir_jra55+'/'+ifil_jra55]], input_var_name='UGRD_GDS0_ISBL')

  jra55_daily.calculate_filedatetime_info(Diag=False, calendar='proleptic_gregorian', time='initial_time0_hours')

  jra55_daily.get_latlon_info(Diag=False, lat='g0_lat_2', lon='g0_lon_3')
  
  jra55_daily_quantity=jra55_daily.calculate_quantity('dummy', Diag=False, quantity='latlon_region')

  print('jra55_daily_quantity.shape=',jra55_daily_quantity.shape)

  jra55_daily.daily_monthly_indices_info(timesep=24) #would be 1 for daily data and 24 for hourly data.

  jra55_monthly_from_daily=jra55_daily.daily_to_monthly(EndOption=1, input=jra55_daily_quantity)
  
  jra55_quantity_monthlyclimatology_from_daily, jra55_quantity_monthlyanomaly_from_daily = jra55_daily.monthly_clim_anom( \
    Diag=False, input=jra55_monthly_from_daily, AnnOut=AnnOut, ZeroClim=ZeroClim, \
    cbeg=cbeg_jra55, cend=cend_jra55, abeg=abeg_jra55, aend=aend_jra55)   

  jra55_shape=jra55_quantity_monthlyanomaly_from_daily.shape
  
  if(plev_cnt==0):
    jra55_monthlyanomaly_ugrd=ma.zeros((jra55_shape[0],len(plevs_jra55),jra55_daily.nlat,jra55_daily.nlon),dtype=float)
    jra55_monthlyclimatology_ugrd=ma.zeros((12,len(plevs_jra55),jra55_daily.nlat,jra55_daily.nlon),dtype=float)
    
  jra55_monthlyanomaly_ugrd[:,plev_cnt,:,:] = np.squeeze(jra55_quantity_monthlyanomaly_from_daily)
  jra55_monthlyclimatology_ugrd[:,plev_cnt,:,:] = np.squeeze(jra55_quantity_monthlyclimatology_from_daily)
  
  print('jra55_quantity_monthlyanomaly_from_daily.shape=',jra55_quantity_monthlyanomaly_from_daily.shape)

print('END')
# Out:
# BEGIN
# [1, 2, 3, 5, 7, 10, 20, 30, 50, 70, 100, 125, 150, 175, 200, 225, 250, 300, 350, 400, 450, 500, 550, 600, 650, 750, 775, 800, 825, 850, 875, 900, 925, 950, 975, 1000]
# plev_cnt,plev= 0 1
# Input file= /OSM/CBR/OA_DCFP/data/observations/JRA55/isobaric/033_ugrd/cat/jra.55.ugrd.1.1958010100_2016123118.nc
# n_data_funcs.init: no ensembles in this example.
# calculate_filedatetime_info: case 1: no ensembles, one input file.
# calculate_quantity: value_split= ['latlon_region']
# n_data_funcs.calculate_quantity: Using whole lat/lon region or that specified in instance.
# jra55_daily_quantity.shape= (21550, 1, 145, 288)
# daily_to_monthly: Discarding beg&/end month if they exist.
# daily_to_monthly: type#4
# Diag= False
# monthly_clim_anom: All years have 12 months.
# jra55_quantity_monthlyanomaly_from_daily.shape= (708, 1, 145, 288)
# plev_cnt,plev= 1 2
# Input file= /OSM/CBR/OA_DCFP/data/observations/JRA55/isobaric/033_ugrd/cat/jra.55.ugrd.2.1958010100_2016123118.nc
# ...

# %%
print('BEGIN')

#print(jra55_daily.lat[68:76+1])

xysize=(6,4)

shade_2d_simple(np.average(np.average(jra55_monthlyclimatology_ugrd,axis=0),axis=2), \
  title='jra55', units='m/s', \
  reverse_yaxis=True, yscale='log', \
  xyvals=(jra55_daily.lat, plevs_jra55), \
  xysize=xysize, xlab='Latitude', ylab='Pressure (hPa)', ytik=[10,100,500,1000], grid=True, clevs=None, n_contour=[0])

xysize=(18,8)

shade_2d_simple(np.transpose(np.average(np.average(jra55_monthlyanomaly_ugrd[:,:,68:76+1,:],axis=3),axis=2)), \
  title='jra55', units='m/s', \
  reverse_yaxis=True, yscale='log', \
  xyvals=(jra55_daily.year_fraction_anomaly, plevs_jra55), \
  xysize=xysize, xlab='Time (Year)', ylab='Pressure (hPa)', ytik=[10,100,500,1000], grid=True, clevs=None, n_contour=[0])

print('END')
# Out:
# BEGIN
# END

# %%
print('BEGIN')

'''
2d

https://scipy-cookbook.readthedocs.io/items/ButterworthBandpass.html

'''

from scipy.signal import butter, lfilter

def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y

import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import freqz

# Sample rate and desired cutoff frequencies (in Hz).
jra55_fs = 300 #300
jra55_lowcut = 9 #9
jra55_highcut = 48 #48

# Plot the frequency response for a few different orders.
plt.figure(1)
plt.clf()
for order in [3, 6, 9]:
    b, a = butter_bandpass(jra55_lowcut, jra55_highcut, jra55_fs, order=order)
    w, h = freqz(b, a, worN=2000)
    plt.plot((jra55_fs * 0.5 / np.pi) * w, abs(h), label="order = %d" % order)

plt.plot([0, 0.5 * jra55_fs], [np.sqrt(0.5), np.sqrt(0.5)],
         '--', label='sqrt(0.5)')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Gain')
plt.grid(True)
plt.legend(loc='best')

# Filter a noisy signal.
jra55_T = 0.05

xysize=(18,6)

jra55_raw = np.average(np.average(jra55_monthlyanomaly_ugrd[:,:,68:76+1,:], axis=3), axis=2)

jra55_filtered = ma.zeros(jra55_raw.shape, dtype=float)

x_min=0;x_max=708 #full range
x_min=0;x_max=240 #first 20 years
x_min=72;x_max=384 #1964-1990

y_min=0;y_max=36 #full range
y_min=0;y_max=11 #1-100hPa

for plev_cnt,plev in enumerate(plevs_jra55):
  #print('plev_cnt,plev=',plev_cnt,plev)
  jra55_filtered[:, plev_cnt] = butter_bandpass_filter(jra55_raw[:, plev_cnt], jra55_lowcut, jra55_highcut, jra55_fs, order=6)

shade_2d_simple(np.transpose(jra55_raw[x_min:x_max, y_min:y_max]), \
  title='jra55 raw', units='m/s', \
  reverse_yaxis=True, yscale='log', \
  xyvals=(jra55_daily.year_fraction_anomaly[x_min:x_max], plevs_jra55[y_min:y_max]), \
  xysize=xysize, xlab='Time (Year)', ylab='Pressure (hPa)', ytik=[5,10,50,100], grid=True, clevs=None)

shade_2d_simple(np.transpose(jra55_filtered[x_min:x_max, y_min:y_max]), \
  title='jra55 filtered (9-48 month bandpass)', units='m/s', \
  reverse_yaxis=True, yscale='log', \
  xyvals=(jra55_daily.year_fraction_anomaly[x_min:x_max], plevs_jra55[y_min:y_max]), \
  xysize=xysize, xlab='Time (Year)', ylab='Pressure (hPa)', ytik=[5,10,50,100], grid=True, clevs=None)

print('END')
# Out:
# BEGIN
# END

# %%
print('BEGIN')

'''
1d
'''

from scipy.signal import butter, lfilter

def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y

import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import freqz

# Sample rate and desired cutoff frequencies (in Hz).
jra55_fs = 200 #100
jra55_lowcut = 9 #9
jra55_highcut = 48 #48

# Plot the frequency response for a few different orders.
plt.figure(1)
plt.clf()
for order in [3, 6, 9]:
    b, a = butter_bandpass(jra55_lowcut, jra55_highcut, jra55_fs, order=order)
    w, h = freqz(b, a, worN=2000)
    plt.plot((jra55_fs * 0.5 / np.pi) * w, abs(h), label="order = %d" % order)

plt.plot([0, 0.5 * jra55_fs], [np.sqrt(0.5), np.sqrt(0.5)],
         '--', label='sqrt(0.5)')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Gain')
plt.grid(True)
plt.legend(loc='best')

# Filter a noisy signal.
jra55_T = 0.05
nsamples = jra55_T * jra55_fs

jra55_x=np.average(np.average(jra55_monthlyanomaly_ugrd[:,10,68:76+1,:],axis=2),axis=1)
jra55_t=jra55_daily.year_fraction_anomaly

plt.figure(2)
plt.clf()
plt.plot(jra55_t, jra55_x, label='jra55')

jra55_y = butter_bandpass_filter(jra55_x, jra55_lowcut, jra55_highcut, jra55_fs, order=6)
plt.plot(jra55_t, jra55_y, label='Filtered signal')
plt.xlabel('Time (year)')
#plt.hlines([-a, a], 0, jra55_T, linestyles='--')
plt.grid(True)
plt.axis('tight')
plt.legend(loc='upper left')

plt.show()

print('END')
# Out:
# BEGIN
# END

# %%
from scipy.signal import butter, lfilter

def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a


def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y


import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import freqz

# Sample rate and desired cutoff frequencies (in Hz).
fs = 5000.0
lowcut = 500.0
highcut = 2400.0 #1250.0, needs to be less than 2500.0

# Plot the frequency response for a few different orders.
plt.figure(1)
plt.clf()
for order in [3, 6, 9]:
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    w, h = freqz(b, a, worN=2000)
    plt.plot((fs * 0.5 / np.pi) * w, abs(h), label="order = %d" % order)

plt.plot([0, 0.5 * fs], [np.sqrt(0.5), np.sqrt(0.5)],
         '--', label='sqrt(0.5)')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Gain')
plt.grid(True)
plt.legend(loc='best')

# Filter a noisy signal.
T = 0.05
nsamples = T * fs
t = np.linspace(0, T, nsamples, endpoint=False)
a = 0.02
f0 = 600.0
x = 0.1 * np.sin(2 * np.pi * 1.2 * np.sqrt(t))
x += 0.01 * np.cos(2 * np.pi * 312 * t + 0.1)
x += a * np.cos(2 * np.pi * f0 * t + .11)
x += 0.03 * np.cos(2 * np.pi * 2000 * t)
plt.figure(2)
plt.clf()
plt.plot(t, x, label='Noisy signal')

y = butter_bandpass_filter(x, lowcut, highcut, fs, order=6)
plt.plot(t, y, label='Filtered signal (%g Hz)' % f0)
plt.xlabel('time (seconds)')
plt.hlines([-a, a], 0, T, linestyles='--')
plt.grid(True)
plt.axis('tight')
plt.legend(loc='upper left')

plt.show()
# Out:
# jupyter_notebook:44: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
